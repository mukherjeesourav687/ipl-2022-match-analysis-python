# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv('IPL.csv')
df.head()
# Out:
#    match_id           date                                         venue  \
# 0         1  March 26,2022                      Wankhede Stadium, Mumbai
# 1         2  March 27,2022                     Brabourne Stadium, Mumbai
# 2         3  March 27,2022            Dr DY Patil Sports Academy, Mumbai
# 3         4  March 28,2022                      Wankhede Stadium, Mumbai
# 4         5  March 29,2022  Maharashtra Cricket Association Stadium,Pune
#
#        team1      team2  stage toss_winner toss_decision  first_ings_score  \
# 0    Chennai    Kolkata  Group     Kolkata         Field               131
# 1      Delhi     Mumbai  Group       Delhi         Field               177
# 2   Banglore     Punjab  Group      Punjab         Field               205
# 3    Gujarat    Lucknow  Group     Gujarat         Field               158
# 4  Hyderabad  Rajasthan  Group   Hyderabad         Field               210
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 74 entries, 0 to 73
# Data columns (total 20 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   match_id             74 non-null     int64
#  1   date                 74 non-null     str
#  2   venue                74 non-null     str
#  3   team1                74 non-null     str
#  4   team2                74 non-null     str
#  5   stage                74 non-null     str
#  6   toss_winner          74 non-null     str
#  7   toss_decision        74 non-null     str
#  8   first_ings_score     74 non-null     int64
#  9   first_ings_wkts      74 non-null     int64
#  10  second_ings_score    74 non-null     int64
#  11  second_ings_wkts     74 non-null     int64
#  12  match_winner         74 non-null     str
#  13  won_by               74 non-null     str
#  14  margin               74 non-null     int64
#  15  player_of_the_match  74 non-null     str
# ...

# %%
df.describe()
# Out:
#         match_id  first_ings_score  first_ings_wkts  second_ings_score  \
# count  74.000000         74.000000        74.000000          74.000000
# mean   37.500000        171.121622         6.135135         158.540541
# std    21.505813         29.048355         2.222699          29.299207
# min     1.000000         68.000000         0.000000          72.000000
# 25%    19.250000        154.250000         5.000000         142.750000
# 50%    37.500000        169.500000         6.000000         160.000000
# 75%    55.750000        192.750000         8.000000         176.000000
# max    74.000000        222.000000        10.000000         211.000000
#
#        second_ings_wkts     margin   highscore
# count         74.000000  74.000000   74.000000
# mean           6.175676  16.972973   71.716216
# std            2.639832  19.651047   20.705052
# min            1.000000   2.000000   28.000000
# 25%            4.000000   5.250000   57.000000
# ...

# %%
df.shape
# Out:
# (74, 20)

# %%
df.size
# Out:
# 1480

# %%
df.isnull().sum()
# Out:
# match_id               0
# date                   0
# venue                  0
# team1                  0
# team2                  0
# stage                  0
# toss_winner            0
# toss_decision          0
# first_ings_score       0
# first_ings_wkts        0
# second_ings_score      0
# second_ings_wkts       0
# match_winner           0
# won_by                 0
# margin                 0
# player_of_the_match    0
# top_scorer             0
# highscore              0
# best_bowling           0
# best_bowling_figure    0
# dtype: int64

# %% [markdown]
# ## Question: Which team won the most matches?

# %%
match_wins = df['match_winner'].value_counts()
match_wins
# Out:
# match_winner
# Gujarat      12
# Rajasthan    10
# Banglore      9
# Lucknow       9
# Delhi         7
# Punjab        7
# Kolkata       6
# Hyderabad     6
# Chennai       4
# Mumbai        4
# Name: count, dtype: int64

# %%
sns.barplot(y=match_wins.index, x=match_wins.values, palette='viridis')
plt.title('Number of Matches Won by Each Team')
# Out:
# Text(0.5, 1.0, 'Number of Matches Won by Each Team')

# %% [markdown]
# ## Question: What are the toss decision trends?

# %%
sns.countplot(x=df['toss_decision'], palette='rainbow')
plt.title('Toss Decision Trends')
# Out:
# Text(0.5, 1.0, 'Toss Decision Trends')

# %% [markdown]
# ## Question: What percentage of toss winners also won the match?

# %%
count = df[df["toss_winner"] == df["match_winner"]][["match_id"]].count()
percentage = (count * 100)/df.shape[0]
percentage.round(2)
# Out:
# match_id    48.65
# dtype: float64

# %% [markdown]
# ## Question: How do teams win? (Runs vs Wickets)

# %%
sns.countplot(x='won_by', data=df, palette='Set1')
plt.title('Winning Margin Types')
# Out:
# Text(0.5, 1.0, 'Winning Margin Types')

# %% [markdown]
# ## Question: Who received the most Player of the Match awards?

# %%
count = df['player_of_the_match'].value_counts().head(10)
count
# Out:
# player_of_the_match
# Kuldeep Yadav        4
# Jos Buttler          3
# Umesh Yadav          2
# Wanindu Hasaranga    2
# Avesh Khan           2
# Dinesh Karthik       2
# Quinton de Kock      2
# Shubman Gill         2
# Yuzvendra Chahal     2
# Hardik Pandya        2
# Name: count, dtype: int64

# %%
sns.barplot(x = count.values , y = count.index,palette='mako')
plt.title("Top 10 plauers with man of the match")
# Out:
# Text(0.5, 1.0, 'Top 10 plauers with man of the match')

# %% [markdown]
# ## Question: Who were the top scorers?

# %%
high = df.groupby('top_scorer')['highscore'].sum().sort_values(ascending=False).head(2)
high
# Out:
# top_scorer
# Jos Buttler        651
# Quinton de Kock    377
# Name: highscore, dtype: int64

# %%
high.plot(kind = 'barh')
# Out:
# <Axes: ylabel='top_scorer'>

# %%
df.head()
# Out:
#    match_id           date                                         venue  \
# 0         1  March 26,2022                      Wankhede Stadium, Mumbai
# 1         2  March 27,2022                     Brabourne Stadium, Mumbai
# 2         3  March 27,2022            Dr DY Patil Sports Academy, Mumbai
# 3         4  March 28,2022                      Wankhede Stadium, Mumbai
# 4         5  March 29,2022  Maharashtra Cricket Association Stadium,Pune
#
#        team1      team2  stage toss_winner toss_decision  first_ings_score  \
# 0    Chennai    Kolkata  Group     Kolkata         Field               131
# 1      Delhi     Mumbai  Group       Delhi         Field               177
# 2   Banglore     Punjab  Group      Punjab         Field               205
# 3    Gujarat    Lucknow  Group     Gujarat         Field               158
# 4  Hyderabad  Rajasthan  Group   Hyderabad         Field               210
#
# ...

# %% [markdown]
# ## Question: Which bowlers had the best bowling figures?

# %%
df['highest_wickets'] = df['best_bowling_figure'].apply(lambda x :x.split('--')[0])
df['highest_wickets'] = df['highest_wickets'].astype(int)
top_bowlers = df.groupby('best_bowling')['highest_wickets'].sum().sort_values(ascending=False).head(10)
top_bowlers.plot(kind = 'barh')
# Out:
# <Axes: ylabel='best_bowling'>

# %% [markdown]
# ## Question: Which venue hosted the most matches?

# %%
venue_count = df['venue'].value_counts()
venue_count
# Out:
# venue
# Wankhede Stadium, Mumbai                        21
# Dr DY Patil Sports Academy, Mumbai              20
# Brabourne Stadium, Mumbai                       16
# Maharashtra Cricket Association Stadium,Pune    13
# Eden Gardens, Kolkata                            2
# Narendra Modi Stadium, Ahmedabad                 2
# Name: count, dtype: int64

# %%
sns.barplot(y = venue_count.index,x = venue_count.values,palette='rainbow')
# Out:
# <Axes: ylabel='venue'>

# %% [markdown]
# ## Custom Question 1: Who won by the highest margin (runs)?

# %%
df[df['won_by'] == 'Runs'].sort_values(by = 'margin',ascending=False).head(1)[['match_winner','margin']]
# Out:
#    match_winner  margin
# 54      Chennai      91

# %% [markdown]
# ## Custom Question 2: Which player had the highest individual score?

# %%
df[df['highscore'] == df['highscore'].max()][['top_scorer','highscore']]
# Out:
#          top_scorer  highscore
# 65  Quinton de Kock        140

# %% [markdown]
# ## Custom Question 3: Which bowler had the best bowling figures?

# %%
df[df['highest_wickets'] == df['highest_wickets'].max()][['best_bowling','best_bowling_figure']].sort_values(by = 'best_bowling_figure')
# Out:
#          best_bowling best_bowling_figure
# 55     Jasprit Bumrah               5--10
# 53  Wanindu Hasaranga               5--18
# 39        Umran Malik               5--25
# 29   Yuzvendra Chahal               5--40
